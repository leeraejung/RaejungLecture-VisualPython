# %% [markdown]
# <img src="https://i.esdrop.com/d/7o0dj05m8rnz/JNGCMedl18.png" width="45%">

# %% [markdown]
# # 분류 - 건강 상태

# %% [markdown]
# - 건강상태(General_Health)를 예측

# %% [markdown]
# ---

# %%
# Visual Python: Data Analysis > Import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Visual Python: Data Analysis > File
df = pd.read_csv('./data/health.csv')
df
# Out:
#              ID General_Health                  Checkup Exercise  \
# 0       ID_1473           Good  Within the past 2 years      Yes
# 1       ID_2045           Good  Within the past 2 years      Yes
# 2       ID_3079           Good     Within the past year      Yes
# 3      ID_15958      Excellent     Within the past year      Yes
# 4      ID_11047      Excellent     Within the past year      Yes
# ...         ...            ...                      ...      ...
# 11225  ID_10059      Excellent     Within the past year      Yes
# 11226   ID_2220           Good  Within the past 2 years      Yes
# 11227   ID_6545           Fair      5 or more years ago      Yes
# 11228  ID_13725      Excellent     Within the past year      Yes
# 11229   ID_4890           Good     Within the past year       No
#
#       Heart_Disease Skin_Cancer Other_Cancer Depression Diabetes Arthritis  \
# 0                No          No           No         No       No       Yes
# 1                No          No           No         No       No        No
# 2                No          No           No        Yes       No       Yes
# 3                No          No           No         No       No        No
# 4                No          No          Yes         No       No        No
# ...             ...         ...          ...        ...      ...       ...
# 11225            No          No           No         No       No        No
# 11226            No          No           No        Yes       No        No
# 11227            No          No           No         No       No        No
# 11228            No          No           No         No       No        No
# 11229           Yes          No           No         No      Yes        No
#
#           Sex Age_Category  Height_(cm)  Weight_(kg)    BMI Smoking_History  \
# 0      Female        55-59        168.0        77.11  27.44              No
# 1      Female        40-44        152.0        58.97  25.39              No
# 2      Female        65-69        170.0        65.77  22.71             Yes
# 3      Female        40-44        163.0        56.70  21.46              No
# 4        Male        55-59        185.0        95.25  27.71             Yes
# ...       ...          ...          ...          ...    ...             ...
# 11225  Female        70-74        163.0        49.90  18.88              No
# 11226    Male        18-24        170.0        99.79  34.46              No
# 11227    Male        60-64        178.0        68.04  21.52              No
# 11228    Male        45-49        201.0       112.94  28.05             Yes
# 11229    Male          80+        180.0        88.45  27.20             Yes
#
#        Alcohol_Consumption  Fruit_Consumption  Green_Vegetables_Consumption  \
# 0                      1.0               12.0                           4.0
# 1                      0.0                8.0                          16.0
# 2                     12.0               30.0                           2.0
# 3                     24.0               60.0                          16.0
# 4                     28.0               30.0                          30.0
# ...                    ...                ...                           ...
# 11225                  0.0               20.0                          20.0
# 11226                  3.0               10.0                           5.0
# 11227                 16.0               30.0                           4.0
# 11228                  4.0                0.0                          14.0
# 11229                  1.0               60.0                           8.0
#
#        FriedPotato_Consumption
# 0                          4.0
# 1                          8.0
# 2                          0.0
# 3                          3.0
# 4                          8.0
# ...                        ...
# 11225                      4.0
# 11226                     30.0
# 11227                      8.0
# 11228                      0.0
# 11229                      2.0
#
# [11230 rows x 20 columns]

# %%
# Visual Python: Data Analysis > Data Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11230 entries, 0 to 11229
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            11230 non-null  object
#  1   General_Health                11230 non-null  object
#  2   Checkup                       11230 non-null  object
#  3   Exercise                      11230 non-null  object
#  4   Heart_Disease                 11230 non-null  object
#  5   Skin_Cancer                   11230 non-null  object
#  6   Other_Cancer                  11230 non-null  object
#  7   Depression                    11230 non-null  object
#  8   Diabetes                      11230 non-null  object
#  9   Arthritis                     11230 non-null  object
#  10  Sex                           11230 non-null  object
#  11  Age_Category                  11230 non-null  object
#  12  Height_(cm)                   11230 non-null  float64
#  13  Weight_(kg)                   11230 non-null  float64
#  14  BMI                           11230 non-null  float64
#  15  Smoking_History               11230 non-null  object
#  16  Alcohol_Consumption           11230 non-null  float64
#  17  Fruit_Consumption             11230 non-null  float64
#  18  Green_Vegetables_Consumption  11230 non-null  float64
#  19  FriedPotato_Consumption       11230 non-null  float64
# dtypes: float64(7), object(13)
# memory usage: 1.7+ MB

# %%
# Visual Python: Data Analysis > Data Info
df.describe()
# Out:
#         Height_(cm)   Weight_(kg)           BMI  Alcohol_Consumption  \
# count  11230.000000  11230.000000  11230.000000         11230.000000
# mean     170.532769     83.881470     28.769485             4.826714
# std       10.766101     22.177621      6.925065             8.072258
# min       94.000000     31.750000     13.250000             0.000000
# 25%      163.000000     68.040000     24.050000             0.000000
# 50%      170.000000     81.650000     27.440000             1.000000
# 75%      178.000000     95.250000     32.037500             5.000000
# max      226.000000    293.020000     97.580000            30.000000
#
#        Fruit_Consumption  Green_Vegetables_Consumption  \
# count       11230.000000                  11230.000000
# mean           29.451113                     15.112467
# std            25.039505                     15.374689
# min             0.000000                      0.000000
# 25%            12.000000                      4.000000
# 50%            30.000000                     12.000000
# 75%            30.000000                     20.000000
# max           120.000000                    120.000000
#
#        FriedPotato_Consumption
# count             11230.000000
# mean                  6.320125
# std                   8.393891
# min                   0.000000
# 25%                   2.000000
# 50%                   4.000000
# 75%                   8.000000
# max                 120.000000

# %%
# Visual Python: Data Analysis > Data Info
pd.DataFrame({'Null Count': df.isnull().sum(), 'Non-Null Count': df.notnull().sum()})
# Out:
#                               Null Count  Non-Null Count
# ID                                     0           11230
# General_Health                         0           11230
# Checkup                                0           11230
# Exercise                               0           11230
# Heart_Disease                          0           11230
# Skin_Cancer                            0           11230
# Other_Cancer                           0           11230
# Depression                             0           11230
# Diabetes                               0           11230
# Arthritis                              0           11230
# Sex                                    0           11230
# Age_Category                           0           11230
# Height_(cm)                            0           11230
# Weight_(kg)                            0           11230
# BMI                                    0           11230
# Smoking_History                        0           11230
# Alcohol_Consumption                    0           11230
# Fruit_Consumption                      0           11230
# Green_Vegetables_Consumption           0           11230
# FriedPotato_Consumption                0           11230

# %%
# Visual Python: Data Analysis > Data Info
df['General_Health'].value_counts()
# Out:
# Excellent    4286
# Good         3990
# Fair         2954
# Name: General_Health, dtype: int64

# %% [markdown]
# ####  컬럼(ID) 삭제

# %%
# Visual Python: Data Analysis > Frame
df.drop(['ID'], axis=1, inplace=True)
df
# Out:
#       General_Health                  Checkup Exercise Heart_Disease  \
# 0               Good  Within the past 2 years      Yes            No
# 1               Good  Within the past 2 years      Yes            No
# 2               Good     Within the past year      Yes            No
# 3          Excellent     Within the past year      Yes            No
# 4          Excellent     Within the past year      Yes            No
# ...              ...                      ...      ...           ...
# 11225      Excellent     Within the past year      Yes            No
# 11226           Good  Within the past 2 years      Yes            No
# 11227           Fair      5 or more years ago      Yes            No
# 11228      Excellent     Within the past year      Yes            No
# 11229           Good     Within the past year       No           Yes
#
#       Skin_Cancer Other_Cancer Depression Diabetes Arthritis     Sex  \
# 0              No           No         No       No       Yes  Female
# 1              No           No         No       No        No  Female
# 2              No           No        Yes       No       Yes  Female
# 3              No           No         No       No        No  Female
# 4              No          Yes         No       No        No    Male
# ...           ...          ...        ...      ...       ...     ...
# 11225          No           No         No       No        No  Female
# 11226          No           No        Yes       No        No    Male
# 11227          No           No         No       No        No    Male
# 11228          No           No         No       No        No    Male
# 11229          No           No         No      Yes        No    Male
#
#       Age_Category  Height_(cm)  Weight_(kg)    BMI Smoking_History  \
# 0            55-59        168.0        77.11  27.44              No
# 1            40-44        152.0        58.97  25.39              No
# 2            65-69        170.0        65.77  22.71             Yes
# 3            40-44        163.0        56.70  21.46              No
# 4            55-59        185.0        95.25  27.71             Yes
# ...            ...          ...          ...    ...             ...
# 11225        70-74        163.0        49.90  18.88              No
# 11226        18-24        170.0        99.79  34.46              No
# 11227        60-64        178.0        68.04  21.52              No
# 11228        45-49        201.0       112.94  28.05             Yes
# 11229          80+        180.0        88.45  27.20             Yes
#
#        Alcohol_Consumption  Fruit_Consumption  Green_Vegetables_Consumption  \
# 0                      1.0               12.0                           4.0
# 1                      0.0                8.0                          16.0
# 2                     12.0               30.0                           2.0
# 3                     24.0               60.0                          16.0
# 4                     28.0               30.0                          30.0
# ...                    ...                ...                           ...
# 11225                  0.0               20.0                          20.0
# 11226                  3.0               10.0                           5.0
# 11227                 16.0               30.0                           4.0
# 11228                  4.0                0.0                          14.0
# 11229                  1.0               60.0                           8.0
#
#        FriedPotato_Consumption
# 0                          4.0
# 1                          8.0
# 2                          0.0
# 3                          3.0
# 4                          8.0
# ...                        ...
# 11225                      4.0
# 11226                     30.0
# 11227                      8.0
# 11228                      0.0
# 11229                      2.0
#
# [11230 rows x 19 columns]

# %% [markdown]
# #### 범주형 변수: One-Hot Encoding

# %%
# Visual Python: Data Analysis > Frame
df = pd.get_dummies(data=df, columns=['Checkup','Exercise','Heart_Disease','Skin_Cancer','Other_Cancer','Depression','Diabetes','Arthritis','Sex','Age_Category','Smoking_History'])
df
# Out:
#       General_Health  Height_(cm)  Weight_(kg)    BMI  Alcohol_Consumption  \
# 0               Good        168.0        77.11  27.44                  1.0
# 1               Good        152.0        58.97  25.39                  0.0
# 2               Good        170.0        65.77  22.71                 12.0
# 3          Excellent        163.0        56.70  21.46                 24.0
# 4          Excellent        185.0        95.25  27.71                 28.0
# ...              ...          ...          ...    ...                  ...
# 11225      Excellent        163.0        49.90  18.88                  0.0
# 11226           Good        170.0        99.79  34.46                  3.0
# 11227           Fair        178.0        68.04  21.52                 16.0
# 11228      Excellent        201.0       112.94  28.05                  4.0
# 11229           Good        180.0        88.45  27.20                  1.0
#
#        Fruit_Consumption  Green_Vegetables_Consumption  \
# 0                   12.0                           4.0
# 1                    8.0                          16.0
# 2                   30.0                           2.0
# 3                   60.0                          16.0
# 4                   30.0                          30.0
# ...                  ...                           ...
# 11225               20.0                          20.0
# 11226               10.0                           5.0
# 11227               30.0                           4.0
# 11228                0.0                          14.0
# 11229               60.0                           8.0
#
#        FriedPotato_Consumption  Checkup_5 or more years ago  Checkup_Never  \
# 0                          4.0                            0              0
# 1                          8.0                            0              0
# 2                          0.0                            0              0
# 3                          3.0                            0              0
# 4                          8.0                            0              0
# ...                        ...                          ...            ...
# 11225                      4.0                            0              0
# 11226                     30.0                            0              0
# 11227                      8.0                            1              0
# 11228                      0.0                            0              0
# 11229                      2.0                            0              0
#
#        ...  Age_Category_45-49  Age_Category_50-54  Age_Category_55-59  \
# 0      ...                   0                   0                   1
# 1      ...                   0                   0                   0
# 2      ...                   0                   0                   0
# 3      ...                   0                   0                   0
# 4      ...                   0                   0                   1
# ...    ...                 ...                 ...                 ...
# 11225  ...                   0                   0                   0
# 11226  ...                   0                   0                   0
# 11227  ...                   0                   0                   0
# 11228  ...                   1                   0                   0
# 11229  ...                   0                   0                   0
#
#        Age_Category_60-64  Age_Category_65-69  Age_Category_70-74  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   1                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 11225                   0                   0                   1
# 11226                   0                   0                   0
# 11227                   1                   0                   0
# 11228                   0                   0                   0
# 11229                   0                   0                   0
#
#        Age_Category_75-79  Age_Category_80+  Smoking_History_No  \
# 0                       0                 0                   1
# 1                       0                 0                   1
# 2                       0                 0                   0
# 3                       0                 0                   1
# 4                       0                 0                   0
# ...                   ...               ...                 ...
# 11225                   0                 0                   1
# 11226                   0                 0                   1
# 11227                   0                 0                   1
# 11228                   0                 0                   0
# 11229                   0                 1                   0
#
#        Smoking_History_Yes
# 0                        0
# 1                        0
# 2                        1
# 3                        0
# 4                        1
# ...                    ...
# 11225                    0
# 11226                    0
# 11227                    0
# 11228                    1
# 11229                    1
#
# [11230 rows x 46 columns]

# %% [markdown]
# #### 수치형 변수: Min-Max Scaling

# %%
# Visual Python: Machine Learning > Pipeline
# [1] Data Prep
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# [2] Fit
scaler.fit(df[['Height_(cm)', 'Weight_(kg)', 'BMI', 'Alcohol_Consumption', 'Fruit_Consumption', 'Green_Vegetables_Consumption', 'FriedPotato_Consumption']])

# [3] Transform
trans = scaler.transform(df[['Height_(cm)', 'Weight_(kg)', 'BMI', 'Alcohol_Consumption', 'Fruit_Consumption', 'Green_Vegetables_Consumption', 'FriedPotato_Consumption']])

# %%
col_num = ['Height_(cm)','Weight_(kg)','BMI','Alcohol_Consumption',
           'Fruit_Consumption','Green_Vegetables_Consumption','FriedPotato_Consumption']

df[col_num] = trans

# %% [markdown]
# #### General_Health 예측

# %%
# Visual Python: Machine Learning > Pipeline
# [1] Data Split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df[['Height_(cm)', 'Weight_(kg)', 'BMI', 'Alcohol_Consumption', 'Fruit_Consumption', 'Green_Vegetables_Consumption', 'FriedPotato_Consumption', 'Checkup_5 or more years ago', 'Checkup_Never', 'Checkup_Within the past 2 years', 'Checkup_Within the past 5 years', 'Checkup_Within the past year', 'Exercise_No', 'Exercise_Yes', 'Heart_Disease_No', 'Heart_Disease_Yes', 'Skin_Cancer_No', 'Skin_Cancer_Yes', 'Other_Cancer_No', 'Other_Cancer_Yes', 'Depression_No', 'Depression_Yes', 'Diabetes_No', 'Diabetes_No, pre-diabetes or borderline diabetes', 'Diabetes_Yes', 'Diabetes_Yes, but female told only during pregnancy', 'Arthritis_No', 'Arthritis_Yes', 'Sex_Female', 'Sex_Male', 'Age_Category_18-24', 'Age_Category_25-29', 'Age_Category_30-34', 'Age_Category_35-39', 'Age_Category_40-44', 'Age_Category_45-49', 'Age_Category_50-54', 'Age_Category_55-59', 'Age_Category_60-64', 'Age_Category_65-69', 'Age_Category_70-74', 'Age_Category_75-79', 'Age_Category_80+', 'Smoking_History_No', 'Smoking_History_Yes']], df['General_Health'])

# [2] Classifier
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

# [3] Fit
model.fit(X_train, y_train)

# [4] Predict
pred = model.predict(X_test)

# [5] Evaluation
from sklearn import metrics
from IPython.display import display, Markdown
# Confusion Matrix
display(Markdown('### Confusion Matrix'))
display(pd.crosstab(y_test, pred, margins=True))
# Classification report
print(metrics.classification_report(y_test, pred))
# Out:
# ### Confusion Matrix
# col_0           Excellent  Fair  Good   All
# General_Health
# Excellent             797    55   223  1075
# Fair                  110   337   281   728
# Good                  319   246   440  1005
# All                  1226   638   944  2808
#               precision    recall  f1-score   support
#
#    Excellent       0.65      0.74      0.69      1075
#         Fair       0.53      0.46      0.49       728
#         Good       0.47      0.44      0.45      1005
#
#     accuracy                           0.56      2808
#    macro avg       0.55      0.55      0.55      2808
# weighted avg       0.55      0.56      0.55      2808

# %%
# Visual Python: Machine Learning > Model Info
def vp_create_feature_importances(model, X_train=None, sort=False):
    if isinstance(X_train, pd.core.frame.DataFrame):
        feature_names = X_train.columns
    else:
        feature_names = [ 'X{}'.format(i) for i in range(len(model.feature_importances_)) ]
                        
    df_i = pd.DataFrame(model.feature_importances_, index=feature_names, columns=['Feature_importance'])
    df_i['Percentage'] = 100 * df_i['Feature_importance']
    if sort: df_i.sort_values(by='Feature_importance', ascending=False, inplace=True)
    df_i = df_i.round(2)
                        
    return df_i
def vp_plot_feature_importances(model, X_train=None, sort=False, top_count=0):
    df_i = vp_create_feature_importances(model, X_train, sort)
                        
    if sort: 
        if top_count > 0:
            df_i['Percentage'].sort_values().tail(top_count).plot(kind='barh')
        else:
            df_i['Percentage'].sort_values().plot(kind='barh')
    else: 
        df_i['Percentage'].plot(kind='barh')
    plt.xlabel('Feature importance Percentage')
    plt.ylabel('Features')
                        
    plt.show()

# %%
# Visual Python: Machine Learning > Model Info
vp_plot_feature_importances(model, X_train, sort=True, top_count=10)

# %% [markdown]
# ---

# %%
# End of file
